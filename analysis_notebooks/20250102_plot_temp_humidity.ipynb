# %%
import numpy as np
import os, glob
import matplotlib.pyplot as plt

import h5py
import sys
sys.path.append('../')
import analysis_utils as utils

yale_colors = ['#00356b', '#286dc0', '#63aaff', '#4a4a4a']
utils.load_plotting_setting()

# %%
fname = '/Users/yuhan/Downloads/20250102_monitor_temp_humidity_abch/20250102_monitor_temp_humidity.txt'
data = np.genfromtxt(fname, skip_header=58, encoding='ISO-8859-1')

# %%
tt, temp0, humid, temp1 = [data.T[i] for i in range(4)]

# %%
colors = plt.colormaps.get_cmap('tab20b').resampled(8).colors

fig, axes = plt.subplots(2, 1, figsize=(10, 6))

axes[0].plot(tt/3600, temp0, color='#005AB5')
axes[1].plot(tt/3600, humid, color='#E1BE6A')

axes[1].set_xlabel('Time (hours)')
axes[0].set_ylabel('Room temperature ($^\circ$C)')
axes[1].set_ylabel('Relative humidity (%)')

fig.tight_layout()
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\c'
# <>:9: SyntaxWarning: invalid escape sequence '\c'
# /var/folders/mb/1ggr_wms5jz0l7fkkc3b9xg80000gn/T/ipykernel_3048/67427252.py:9: SyntaxWarning: invalid escape sequence '\c'
#   axes[0].set_ylabel('Room temperature ($^\circ$C)')
