# %%
import numpy as np
import os, glob
import matplotlib.pyplot as plt

import h5py
import sys
sys.path.append('../')
import analysis_utils as utils

yale_colors = ['#00356b', '#286dc0', '#63aaff', '#4a4a4a']
utils.load_plotting_setting()

# %%
import importlib
importlib.reload(utils)
# Out:
# /Users/yuhan/work/nanospheres/impulse_analysis/analysis_notebooks/../analysis_utils.py:459: SyntaxWarning: invalid escape sequence '\s'
#   ax.plot(xx*amp2kev, gauss(xx*amp2kev, *gps_normalized), label=f'{pulseamps[i]} keV (noise), $\sigma$ = {gps_normalized[2]:.1f} keV', color=color)
# /Users/yuhan/work/nanospheres/impulse_analysis/analysis_notebooks/../analysis_utils.py:461: SyntaxWarning: invalid escape sequence '\s'
#   ax.plot(xx*amp2kev, gauss(xx*amp2kev, *gps_normalized), label=f'{pulseamps[i]} keV, $\sigma$ = {gps_normalized[2]:.1f} keV', color=color)
# /Users/yuhan/work/nanospheres/impulse_analysis/analysis_notebooks/../analysis_utils.py:466: SyntaxWarning: invalid escape sequence '\s'
#   ax.plot(xx, gauss(xx, *gps[i]), label=f'{pulseamps[i]} keV (noise), $\sigma$ = {gps[i][2]:.1f} keV', color=color)
# /Users/yuhan/work/nanospheres/impulse_analysis/analysis_notebooks/../analysis_utils.py:468: SyntaxWarning: invalid escape sequence '\s'
#   ax.plot(xx, gauss(xx, *gps[i]), label=f'{pulseamps[i]} keV, $\sigma$ = {gps[i][2]:.1f} keV', color=color)
# /Users/yuhan/work/nanospheres/impulse_analysis/analysis_notebooks/../analysis_utils.py:718: SyntaxWarning: invalid escape sequence '\m'
#   ax[1].set_xlabel('Time ($\mu s$)', fontsize=12)
# /Users/yuhan/work/nanospheres/impulse_analysis/analysis_notebooks/../analysis_utils.py:723: SyntaxWarning: invalid escape sequence '\m'
#   ax[2].set_xlabel('Time ($\mu s$)', fontsize=12)
# /Users/yuhan/work/nanospheres/impulse_analysis/analysis_notebooks/../analysis_utils.py:736: SyntaxWarning: invalid escape sequence '\m'
#   ax[3].set_xlabel('Time ($\mu s$)', fontsize=12)
# /Users/yuhan/work/nanospheres/impulse_analysis/analysis_notebooks/../analysis_utils.py:740: SyntaxWarning: invalid escape sequence '\m'
#   ax[4].set_xlabel('Time ($\mu s$)', fontsize=12)
# <module 'analysis_utils' from '/Users/yuhan/work/nanospheres/impulse_analysis/analysis_notebooks/../analysis_utils.py'>

# %%
from datetime import datetime

def plot_rates(sphere, dataset, data_prefix, n_file, bc, rates, ax=None):
    dir = rf'/Volumes/LaCie/dm_data/{sphere}/{dataset}'
    file = os.path.join(dir, f'{data_prefix}0.hdf5')
    f = h5py.File(file, 'r')
    start_time = str(datetime.fromtimestamp(f['data'].attrs['timestamp']))
    f.close()

    if ax is None:
        fig, ax = plt.subplots(figsize=(8, 5))

    ax.plot(bc, rates[0], '-', color=yale_colors[0], label='All', alpha=1)
    ax.plot(bc, rates[1], '-', color=yale_colors[1], label='Detection quality cut', alpha=1)
    ax.plot(bc, rates[2], '-', color=yale_colors[2], label='Detection quality + noise cut', alpha=1)
    ax.plot(bc, rates[3], '-', color=yale_colors[3], label='Detection quality + noise + anti-coincidence cut', alpha=1)

    # ax.legend(frameon=False, fontsize=12)

    ax.set_yscale('log')
    ax.set_xlim(0, 10000)
    ax.set_ylim(1e-8, 500)

    # ax.set_xlabel('Recon. amplitude (keV)')
    # ax.set_ylabel('Differential count (Hz/keV)')
    # ax.set_title(f'Data ({n_file/60:.1f} hours), begins {start_time}')

# %%
sphere = 'sphere_20241219'
datasets = ['20241219_3e-7mbar_alignment0_long',
            '20241220_8e-8mbar_10e_alignment1_long',
           ]

data_prefixs = ['20241219_d_',
                '20241220_d_',
                ]

n_files = [1037, 497]

bc, scaling = None, None
hhs, rates, n_windows = [], [], []
for i, dataset in enumerate(datasets):
    data_dir = f'/Users/yuhan/work/nanospheres/data/dm_data_processed/{sphere}/{dataset}'
    
    _bc, _hhs, _rates, _n, _scaling = utils.get_summed_rates(data_dir, dataset)
    hhs.append(_hhs)
    rates.append(_rates)
    n_windows.append(_n)

    if bc is None:
        bc = _bc
    if scaling is None:
        scaling = _scaling

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

for i in range(len(datasets)):
    ax = axes.flatten()[i]
    plot_rates(sphere, datasets[i], data_prefixs[i], n_files[i], bc, rates[i], ax)
    ax.set_title(f'{i}: {datasets[i]}', fontsize=8)

axes[0]
fig.tight_layout()

# %%
colors = plt.colormaps.get_cmap('tab20b').resampled(len(datasets)).colors
fig, ax = plt.subplots(figsize=(5, 6))

n_search_per_win = (5000 - 150) / 25
time_per_search = 2e-6 * 25
scaling = n_search_per_win * time_per_search * 50  # because of the 50 keV bins

times = [n[-1] * n_search_per_win * time_per_search / 3600 for n in n_windows] # Time in hours for each dataset (aftercut)

for i in range(len(datasets)):
    ax.plot(bc, rates[i][-1], '-', color=colors[i], label=f'Dataset {i} ({times[i]:.1f} hours)', alpha=0.8, linewidth=1)

ax.legend(frameon=False, fontsize=12)

ax.set_yscale('log')
# ax.set_xscale('log')
ax.set_xlim(0, 6000)
ax.set_ylim(1e-8, 500)

ax.set_xlabel('Recon. amplitude (keV)')
ax.set_ylabel('Differential count (Hz/keV)')
# Out:
# Text(0, 0.5, 'Differential count (Hz/keV)')

# %%
hh_sum = np.sum(np.asarray(hhs), axis=0)
n_window_sum = np.sum(np.asarray(n_windows), axis=0)
time_sum = np.sum(np.asarray(times))

from matplotlib.ticker import LogLocator, NullFormatter, MultipleLocator
from scipy.optimize import curve_fit

fig, ax = plt.subplots(figsize=(5, 6))
ax.errorbar(bc, hh_sum[3] / (n_window_sum[3] * scaling), yerr=np.sqrt(hh_sum[3])/(n_window_sum[3]*scaling), fmt='.', color='#005AB5', label=f'All data ({time_sum:.1f} hours)', alpha=1)

# Factor of 2 because we only have half of a Gaussian
gaus_amp = 2 * 1 / (2e-6 * 25)  # (1 s)/(time per search)
sigma = 282

fit_lb, fit_ub = 900, 2000
idx_fit = np.logical_and(bc > fit_lb, bc < fit_ub)
popt, pcov = curve_fit(lambda x, b: utils.gauss(x, gaus_amp/(sigma * np.sqrt(2*np.pi)), 0, b), 
                       bc[idx_fit], (hh_sum[3]/(n_window_sum[3] * scaling))[idx_fit], p0=[280])

xx = np.linspace(0, 3000, 500)
# ax.plot(xx, utils.gauss(xx, gaus_amp/(sigma * np.sqrt(2*np.pi)), 0, sigma), '--', color='#DC3220', label=f'$\sigma$ = {sigma} keV/c')
ax.plot(xx, utils.gauss(xx, gaus_amp/(popt[0] * np.sqrt(2*np.pi)), 0, popt[0]), '--', color='#DC3220', label=f'$\sigma$ = {popt[0]:.1f} keV/c')

ax.legend(frameon=False, fontsize=12)

ax.set_yscale('log')
# ax.set_xscale('log')

ax.set_xlim(0, 6000)
ax.set_ylim(1e-8, 1000)

ax.set_yticks(np.logspace(-8, 3, 12))
locmin = LogLocator(base=10.0, subs=(0.2, 0.4, 0.6, 0.8), numticks=15)
ax.xaxis.set_minor_locator(MultipleLocator(500))
ax.yaxis.set_minor_locator(locmin)
ax.yaxis.set_minor_formatter(NullFormatter())

ax.set_title('Sphere 20241219')
ax.set_xlabel('Reconstructed amplitude (keV/c)')
ax.set_ylabel('Differential count (Hz/keV/c)')
# Out:
# <>:22: SyntaxWarning: invalid escape sequence '\s'
# <>:22: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/mb/1ggr_wms5jz0l7fkkc3b9xg80000gn/T/ipykernel_12015/397331922.py:22: SyntaxWarning: invalid escape sequence '\s'
#   ax.plot(xx, utils.gauss(xx, gaus_amp/(popt[0] * np.sqrt(2*np.pi)), 0, popt[0]), '--', color='#DC3220', label=f'$\sigma$ = {popt[0]:.1f} keV/c')
# Text(0, 0.5, 'Differential count (Hz/keV/c)')

# %%
data_dir = f'/Users/yuhan/work/nanospheres/data/dm_data_processed/{sphere}/{datasets[0]}'
data_prefix = r'20241219_d_'

hists_0 = utils.load_data_hists(data_dir, data_prefix, 1037, 1600)

events_after_cut_0 = utils.get_events_after_cut(hists_0, thr=2000)
print('Number of windows with large events: ', len(events_after_cut_0))
# Out:
# Number of windows with large events:  11

# %%
raw_data_dir = rf'/Volumes/LaCie/dm_data/{sphere}/{datasets[0]}'

c_mv = 5.522e-08
amp2kev = 6927.379154444802

window_length = 5000
bins = np.arange(0, 10000, 50)
bc = 0.5 * (bins[:-1] + bins[1:])

for i, j in events_after_cut_0[:]:
    _, _, _, _, _, _ = utils.plot_hist_events(raw_data_dir, data_prefix, i, j, window_length, bins, bc, c_mv, amp2kev, False, True)
# Out:
# /Volumes/LaCie/dm_data/sphere_20241219/20241219_3e-7mbar_alignment0_long/20241219_d_18.hdf5
# /Volumes/LaCie/dm_data/sphere_20241219/20241219_3e-7mbar_alignment0_long/20241219_d_85.hdf5
# /Volumes/LaCie/dm_data/sphere_20241219/20241219_3e-7mbar_alignment0_long/20241219_d_149.hdf5
# /Volumes/LaCie/dm_data/sphere_20241219/20241219_3e-7mbar_alignment0_long/20241219_d_153.hdf5
# /Volumes/LaCie/dm_data/sphere_20241219/20241219_3e-7mbar_alignment0_long/20241219_d_191.hdf5
# /Volumes/LaCie/dm_data/sphere_20241219/20241219_3e-7mbar_alignment0_long/20241219_d_481.hdf5
# /Volumes/LaCie/dm_data/sphere_20241219/20241219_3e-7mbar_alignment0_long/20241219_d_709.hdf5
# /Volumes/LaCie/dm_data/sphere_20241219/20241219_3e-7mbar_alignment0_long/20241219_d_870.hdf5
# /Volumes/LaCie/dm_data/sphere_20241219/20241219_3e-7mbar_alignment0_long/20241219_d_870.hdf5
# /Volumes/LaCie/dm_data/sphere_20241219/20241219_3e-7mbar_alignment0_long/20241219_d_870.hdf5
# /Volumes/LaCie/dm_data/sphere_20241219/20241219_3e-7mbar_alignment0_long/20241219_d_970.hdf5

# %%
data_dir = f'/Users/yuhan/work/nanospheres/data/dm_data_processed/{sphere}/{datasets[1]}'
data_prefix = r'20241220_d_'

hists_1 = utils.load_data_hists(data_dir, data_prefix, 497, 1600)

events_after_cut_1 = utils.get_events_after_cut(hists_1, thr=2000)
print('Number of windows with large events: ', len(events_after_cut_1))
# Out:
# Number of windows with large events:  42

# %%
raw_data_dir = rf'/Volumes/LaCie/dm_data/{sphere}/{datasets[1]}'

c_mv = 5.522e-08
amp2kev = 6927.379154444802

window_length = 5000
bins = np.arange(0, 10000, 50)
bc = 0.5 * (bins[:-1] + bins[1:])

for i, j in events_after_cut_1[-10:]:
    _, _, _, _, _, _ = utils.plot_hist_events(raw_data_dir, data_prefix, i, j, window_length, bins, bc, c_mv, amp2kev, False, True)
# Out:
# /Volumes/LaCie/dm_data/sphere_20241219/20241220_8e-8mbar_10e_alignment1_long/20241220_d_475.hdf5
# /Volumes/LaCie/dm_data/sphere_20241219/20241220_8e-8mbar_10e_alignment1_long/20241220_d_481.hdf5
# /Volumes/LaCie/dm_data/sphere_20241219/20241220_8e-8mbar_10e_alignment1_long/20241220_d_484.hdf5
# /Volumes/LaCie/dm_data/sphere_20241219/20241220_8e-8mbar_10e_alignment1_long/20241220_d_486.hdf5
# /Volumes/LaCie/dm_data/sphere_20241219/20241220_8e-8mbar_10e_alignment1_long/20241220_d_487.hdf5
# /Volumes/LaCie/dm_data/sphere_20241219/20241220_8e-8mbar_10e_alignment1_long/20241220_d_489.hdf5
# /Volumes/LaCie/dm_data/sphere_20241219/20241220_8e-8mbar_10e_alignment1_long/20241220_d_489.hdf5
# /Volumes/LaCie/dm_data/sphere_20241219/20241220_8e-8mbar_10e_alignment1_long/20241220_d_490.hdf5
# /Volumes/LaCie/dm_data/sphere_20241219/20241220_8e-8mbar_10e_alignment1_long/20241220_d_492.hdf5
# /Volumes/LaCie/dm_data/sphere_20241219/20241220_8e-8mbar_10e_alignment1_long/20241220_d_493.hdf5
